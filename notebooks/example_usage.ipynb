# %% [markdown]
# # Example Usage - Tabular ML Pipeline
#
# Notebook này cung cấp ví dụ cách sử dụng các modules trong pipeline.
#
# **Note**: Đây là template để học cách sử dụng các modules. Sau khi implement các modules, có thể chạy code examples này để test.

# %% [markdown]
# ## Setup

# %%
# Import thư viện
import sys
import numpy as np
import pandas as pd

# Add modules to path
sys.path.append('../modules')
sys.path.append('..')

# Import configuration
from config import CONFIG

print("✓ Setup completed")

# %% [markdown]
# ## Example 1: Data Loading Module

# %%
# TODO: Uncomment sau khi implement data_loader module

# from data_loader import load_data_from_url, create_dataframe, load_data_pipeline
# 
# # Ví dụ 1: Download file từ URL
# url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
# output_path = "../data/example_titanic.csv"
# 
# file_path = load_data_from_url(url, output_path)
# print(f"Downloaded to: {file_path}")
# 
# # Ví dụ 2: Đọc file thành DataFrame
# df, metadata = create_dataframe(file_path)
# print(f"\nDataFrame shape: {df.shape}")
# print(f"Metadata: {metadata}")
# print(f"\nFirst 5 rows:")
# display(df.head())
# 
# # Ví dụ 3: Pipeline hoàn chỉnh (download + load)
# df, metadata = load_data_pipeline(url, output_path)

print("TODO: Implement data_loader module trước")

# %% [markdown]
# ## Example 2: EDA Module

# %%
# TODO: Uncomment sau khi implement eda module

# from eda import (
#     generate_eda_report,
#     plot_correlation_heatmap,
#     plot_missing_values,
#     plot_class_distribution,
#     run_full_eda
# )
# 
# # Giả sử đã có DataFrame 'df' từ example 1
# target_column = 'Survived'  # Cho Titanic dataset
# output_dir = '../reports/eda/example/'
# 
# # Chạy full EDA
# eda_results = run_full_eda(df, target_column, output_dir)
# 
# print("EDA Results:")
# print(f"- Report: {eda_results['report']}")
# print(f"- Correlation heatmap: {eda_results['correlation_heatmap']}")
# print(f"- Missing values chart: {eda_results['missing_values_chart']}")
# print(f"- Class distribution: {eda_results['class_distribution']}")

print("TODO: Implement eda module trước")

# %% [markdown]
# ## Example 3: Preprocessing Module

# %%
# TODO: Uncomment sau khi implement preprocessing module

# from preprocessing import (
#     apply_imputation,
#     apply_encoding,
#     apply_scaling,
#     preprocess_pipeline
# )
# 
# # Example với từng bước riêng lẻ
# 
# # 1. Imputation
# impute_config = {'method': 'SimpleImputer', 'strategy': 'mean'}
# df_imputed, impute_info = apply_imputation(df, impute_config)
# print(f"After imputation: {impute_info}")
# 
# # 2. Encoding
# encode_config = {'method': 'OneHot', 'drop_first': False}
# df_encoded, encode_info = apply_encoding(df_imputed, encode_config)
# print(f"After encoding: {encode_info}")
# 
# # 3. Scaling
# scale_config = {'method': 'StandardScaler'}
# df_scaled, scale_info = apply_scaling(df_encoded, scale_config)
# print(f"After scaling: {scale_info}")
# 
# # Hoặc dùng full pipeline
# X, y, metadata = preprocess_pipeline(
#     df,
#     target_column,
#     CONFIG['preprocessing']
# )
# print(f"\nPreprocessed features shape: {X.shape}")
# print(f"Target shape: {y.shape}")

print("TODO: Implement preprocessing module trước")

# %% [markdown]
# ## Example 4: Feature Engineering Module

# %%
# TODO: Uncomment sau khi implement features module

# from features import apply_pca, save_features, load_features
# 
# # Giả sử đã có X, y từ preprocessing
# 
# # 1. Apply PCA
# pca_config = {'variance_threshold': 0.95}
# X_pca, pca_info = apply_pca(X, pca_config)
# print(f"PCA results:")
# print(f"  Original dims: {X.shape[1]}")
# print(f"  Reduced dims: {X_pca.shape[1]}")
# print(f"  Explained variance: {pca_info['explained_variance']:.4f}")
# 
# # 2. Save features
# save_config = {'format': 'npy', 'path': '../features/example_features'}
# save_path = save_features(X_pca, y, save_config)
# print(f"\nFeatures saved to: {save_path}")
# 
# # 3. Load features
# X_loaded, y_loaded = load_features('../features/example_features', 'npy')
# print(f"\nFeatures loaded:")
# print(f"  X shape: {X_loaded.shape}")
# print(f"  y shape: {y_loaded.shape}")
# 
# # Verify loaded data matches original
# assert np.allclose(X_pca, X_loaded), "Loaded X doesn't match!"
# assert np.allclose(y, y_loaded), "Loaded y doesn't match!"
# print("✓ Save/Load verification passed")

print("TODO: Implement features module trước")

# %% [markdown]
# ## Example 5: Models Module

# %%
# TODO: Uncomment sau khi implement models module

# from models import (
#     train_logistic_regression,
#     train_svm,
#     train_random_forest,
#     train_mlp
# )
# from sklearn.model_selection import train_test_split
# 
# # Split data
# X_train, X_test, y_train, y_test = train_test_split(
#     X_pca, y, test_size=0.2, random_state=42
# )
# 
# # Train Logistic Regression
# lr_params = {'max_iter': 1000, 'random_state': 42}
# lr_model, lr_pred = train_logistic_regression(X_train, y_train, X_test, lr_params)
# print(f"Logistic Regression predictions shape: {lr_pred.shape}")
# 
# # Train SVM
# svm_params = {'kernel': 'rbf', 'C': 1.0, 'random_state': 42}
# svm_model, svm_pred = train_svm(X_train, y_train, X_test, svm_params)
# print(f"SVM predictions shape: {svm_pred.shape}")
# 
# # Train Random Forest
# rf_params = {'n_estimators': 100, 'random_state': 42}
# rf_model, rf_pred = train_random_forest(X_train, y_train, X_test, rf_params)
# print(f"Random Forest predictions shape: {rf_pred.shape}")
# 
# # Train MLP (Deep Learning)
# mlp_params = {
#     'hidden_layers': [64, 32],
#     'activation': 'relu',
#     'dropout_rate': 0.3,
#     'learning_rate': 0.001,
#     'epochs': 30,
#     'batch_size': 32,
#     'validation_split': 0.2
# }
# mlp_model, mlp_pred = train_mlp(X_train, y_train, X_test, mlp_params)
# print(f"MLP predictions shape: {mlp_pred.shape}")

print("TODO: Implement models module trước")

# %% [markdown]
# ## Example 6: Evaluation Module

# %%
# TODO: Uncomment sau khi implement evaluation module

# from evaluation import (
#     compute_metrics,
#     plot_confusion_matrix,
#     plot_roc_auc,
#     evaluate_model,
#     compare_models
# )
# 
# # Compute metrics
# metrics = compute_metrics(y_test, lr_pred, ['accuracy', 'precision', 'recall', 'f1'])
# print("Logistic Regression Metrics:")
# for metric, value in metrics.items():
#     print(f"  {metric}: {value:.4f}")
# 
# # Plot confusion matrix
# cm_path = plot_confusion_matrix(y_test, lr_pred, '../reports/evaluation/example_cm.png')
# print(f"\nConfusion matrix saved to: {cm_path}")
# 
# # Plot ROC-AUC (nếu có probabilities)
# if hasattr(lr_model, 'predict_proba'):
#     y_proba = lr_model.predict_proba(X_test)[:, 1]
#     roc_path = plot_roc_auc(y_test, y_proba, '../reports/evaluation/example_roc.png')
#     print(f"ROC-AUC curve saved to: {roc_path}")
# 
# # Full evaluation
# eval_config = CONFIG['evaluation']
# eval_results = evaluate_model(
#     y_test, lr_pred, y_proba,
#     'LogisticRegression',
#     '../reports/evaluation/example/',
#     eval_config
# )
# print(f"\nFull evaluation results: {eval_results}")
# 
# # Compare multiple models
# results = {
#     'LogisticRegression': {'predictions': lr_pred, 'metrics': compute_metrics(y_test, lr_pred)},
#     'SVM': {'predictions': svm_pred, 'metrics': compute_metrics(y_test, svm_pred)},
#     'RandomForest': {'predictions': rf_pred, 'metrics': compute_metrics(y_test, rf_pred)},
#     'MLP': {'predictions': mlp_pred, 'metrics': compute_metrics(y_test, mlp_pred)}
# }
# compare_path = compare_models(results, '../reports/evaluation/example_comparison.png')
# print(f"\nModel comparison saved to: {compare_path}")

print("TODO: Implement evaluation module trước")

# %% [markdown]
# ## Summary
#
# Notebook này đã minh họa cách sử dụng từng module trong pipeline:
#
# 1. **data_loader**: Download và load data
# 2. **eda**: Phân tích và visualize data
# 3. **preprocessing**: Imputation, encoding, scaling
# 4. **features**: PCA và save/load features
# 5. **models**: Train các models
# 6. **evaluation**: Đánh giá và compare models
#
# ### Next Steps
# - Implement các TODO trong từng module
# - Test với examples trong notebook này
# - Chạy full pipeline trong `main_pipeline.ipynb`
# - Experiment với different configurations
